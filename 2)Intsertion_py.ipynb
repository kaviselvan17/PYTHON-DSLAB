# %% [markdown]
# <a href="https://colab.research.google.com/github/kaviselvan17/PYTHON-DSLAB/blob/main/2)Intsertion_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class CircularLinkedList:
    def __init__(self):
        self.last = None

    # Add a node to an empty list
    def addToEmpty(self, data):
        if self.last is not None:
            return self.last

        temp = Node(data)
        self.last = temp
        self.last.next = self.last

        return self.last

    # Add a node at the beginning
    def addBegin(self, data):
        if self.last is None:
            return self.addToEmpty(data)

        temp = Node(data)
        temp.next = self.last.next
        self.last.next = temp

        return self.last

    # Add a node at the end
    def addEnd(self, data):
        if self.last is None:
            return self.addToEmpty(data)

        temp = Node(data)
        temp.next = self.last.next
        self.last.next = temp
        self.last = temp

        return self.last

    # Add a node after a given item
    def addAfter(self, data, item):
        if self.last is None:
            return None

        temp = Node(data)
        p = self.last.next

        while p:
            if p.data == item:
                temp.next = p.next
                p.next = temp

                if p == self.last:
                    self.last = temp

                return self.last

            p = p.next

            if p == self.last.next:
                print(item, "not present in the list")
                break

        return self.last

    # Traverse the circular linked list
    def traverse(self):
        if self.last is None:
            print("List is empty")
            return

        temp = self.last.next

        while True:
            print(temp.data, end=" ")
            temp = temp.next

            if temp == self.last.next:
                break

        print()


# Main program
if __name__ == "__main__":

    llist = CircularLinkedList()

    last = llist.addToEmpty(6)
    last = llist.addBegin(4)
    last = llist.addBegin(2)
    last = llist.addEnd(8)
    last = llist.addEnd(12)
    last = llist.addAfter(10, 8)

    llist.traverse()
# Out:
# 2 4 6 8 10 12
